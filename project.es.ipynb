# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl (12.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Angel Resendiz Plata\AppData\Local\Programs\Microsoft VS Code

# %%
import numpy as np
import pandas as pd

# %%
# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
dataset = r"C:\Users\Angel Resendiz Plata\OneDrive\Documentos\Programación\4Geeks\Guía programa\1.- Prework\Proyecto realstate\real_estate.csv"
ds = pd.read_csv(dataset, sep=";")
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# buscar la casa más cara
precio_más_alto = ds["price"].max()
Casa_más_cara = ds[ds["price"] == precio_más_alto]
Dom_casa_más_cara = Casa_más_cara['address'].values[0]
print("La casa ubicada en",Dom_casa_más_cara,"es la más cara y su precio es de",precio_más_alto,"USD")
# Out:
# La casa ubicada en El Escorial es la más cara y su precio es de 8500000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# Buscar la casa más barata
precio_más_bajo = ds["price"].min()
Casa_menos_cara = ds[ds["price"] == precio_más_bajo]
Dom_casa_menos_cara = Casa_menos_cara['address'].values[0]
print("La casa ubicada en",Dom_casa_menos_cara,"es la más barata y su precio es de",precio_más_bajo,"USD")
# Out:
# La casa ubicada en Parla es la más barata y su precio es de 0 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# casas más grande y más chica
Mayor_superficie = ds["surface"].max()
Casa_más_grande = ds[ds["surface"] == Mayor_superficie]
Dom_casa_más_grande = Casa_más_grande['address'].values[0]
print("La casa ubicada en",Dom_casa_más_grande,"es la más grande, con una superficie de ",Mayor_superficie,"metros cuadrados")

Menor_superficie = ds["surface"].min()
Casa_más_chica = ds[ds["surface"] == Menor_superficie]
Dom_casa_más_chica = Casa_más_chica['address'].values[0]
print("La casa ubicada en",Dom_casa_más_chica,"es la más chica, con una superficie de",Menor_superficie,"metros cuadrados")
# Out:
# La casa ubicada en Sevilla la Nueva es la más grande, con una superficie de  249000.0 metros cuadrados
# La casa ubicada en Calle Amparo,  Madrid Capital es la más chica, con una superficie de 15.0 metros cuadrados

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
ds.describe()
# Out:
#          Unnamed: 0  id_realEstates  phone_realEstate         rooms  \
# count  15335.000000    1.533500e+04      1.454100e+04  14982.000000
# mean    7668.000000    1.524371e+08      9.143423e+08      3.231611
# std     4426.977524    2.277286e+06      7.516036e+06      1.393106
# min        1.000000    1.221584e+08      8.762742e+08      1.000000
# 25%     3834.500000    1.519456e+08      9.113649e+08      2.000000
# 50%     7668.000000    1.532413e+08      9.121841e+08      3.000000
# 75%    11501.500000    1.538105e+08      9.148904e+08      4.000000
# max    15335.000000    1.540033e+08      9.887761e+08     30.000000
#
#           bathrooms        surface         price  countryId  level1Id  \
# count  14990.000000   14085.000000  1.533500e+04    15335.0   15335.0
# mean       2.150233     196.916436  4.773036e+05        0.0       0.0
# std        1.292079    2182.758313  5.912942e+05        0.0       0.0
# min        1.000000      15.000000  0.000000e+00        0.0       0.0
# ...

# %%
# todas las poblaciones
poblaciones = ds['level5'].unique()
poblaciones
# Out:
# array(['Arganda del Rey', 'Fuenlabrada', 'Boadilla del Monte',
#        'Las Rozas de Madrid', ' Madrid Capital', 'Villaviciosa de Odón',
#        'Pinto', 'Valdemoro', 'Navalcarnero', 'Pozuelo de Alarcón',
#        'Torrejón de Ardoz', 'Navalagamella', 'San Sebastián de los Reyes',
#        'Rivas-vaciamadrid', 'Alpedrete', 'Móstoles',
#        'San Fernando de Henares', 'Coslada', 'Becerril de la Sierra',
#        'Alcalá de Henares', 'Chinchón', 'Parla', 'Alcorcón',
#        'El Escorial', 'Leganés', 'Pedrezuela', 'Majadahonda',
#        'Villanueva de la Cañada', 'Villanueva del Pardillo',
#        'Torrelodones', 'Moralzarzal', 'Mejorada del Campo', 'Aranjuez',
#        'Corpa', 'Getafe', 'Velilla de San Antonio', 'Sevilla la Nueva',
#        'San Martín de la Vega', 'Villalbilla', 'Collado Villalba',
#        'Alcobendas', 'El Molar (Madrid)', 'Moraleja de Enmedio', 'Algete',
#        'Campo Real', 'Torrejón de la Calzada', 'Colmenar Viejo',
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# buscar valores no admitidos
Val_no_admit = ds.isnull()
Fila_colum = list(zip(*np.where(Val_no_admit)))
for fila, columna in Fila_colum:
    print(True, "; Fila: ", fila, "Columna:", columna)
# Out:
# True ; Fila:  0 Columna: 19
# True ; Fila:  0 Columna: 21
# True ; Fila:  0 Columna: 35
# True ; Fila:  0 Columna: 36
# True ; Fila:  1 Columna: 8
# True ; Fila:  1 Columna: 19
# True ; Fila:  1 Columna: 21
# True ; Fila:  1 Columna: 35
# True ; Fila:  1 Columna: 36
# True ; Fila:  2 Columna: 19
# True ; Fila:  2 Columna: 21
# True ; Fila:  2 Columna: 35
# True ; Fila:  2 Columna: 36
# True ; Fila:  3 Columna: 19
# True ; Fila:  3 Columna: 21
# True ; Fila:  3 Columna: 35
# True ; Fila:  3 Columna: 36
# True ; Fila:  4 Columna: 19
# True ; Fila:  4 Columna: 21
# True ; Fila:  4 Columna: 35
# True ; Fila:  4 Columna: 36
# True ; Fila:  5 Columna: 19
# True ; Fila:  5 Columna: 21
# True ; Fila:  5 Columna: 35
# True ; Fila:  5 Columna: 36
# True ; Fila:  6 Columna: 19
# True ; Fila:  6 Columna: 21
# True ; Fila:  6 Columna: 35
# True ; Fila:  6 Columna: 36
# True ; Fila:  7 Columna: 19
# True ; Fila:  7 Columna: 21
# True ; Fila:  7 Columna: 35
# True ; Fila:  7 Columna: 36
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# hacer una copia y eliminar todos los valores no admitidos
ds_copia = ds.copy()
ds_copia = ds.dropna()
filas,columnas = ds.shape
print("El dataset original cuenta con ", filas, "filas y", columnas,"columnas")
filas,columnas = ds_copia.shape
print("Después de utilizar .dropna el dataset tiene", filas, "filas y", columnas,"columnas")
# Out:
# El dataset original cuenta con  15335 filas y 37 columnas
# Después de utilizar .dropna el dataset tiene 0 filas y 37 columnas

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# media de precios en la población de Arroyomolinos
media_Arroyomolinos = ds[ds["level5"] == "Arroyomolinos (Madrid)"]["price"].mean()
print(media_Arroyomolinos)
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# crear un histograma de level5 para "Arroyomolinos"
import matplotlib.pyplot as plt

Info_Arroyomolinos = ds[ds["level5"] == "Arroyomolinos (Madrid)"]["price"]
plt.hist(Info_Arroyomolinos)
# Out:
# (array([ 2.,  0.,  3., 31., 33., 33., 28.,  3.,  2.,  2.]),
#  array([     0.,  58000., 116000., 174000., 232000., 290000., 348000.,
#         406000., 464000., 522000., 580000.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Se observa una simulación de distribución normal no concretada al concentrarse demasiado la gran mayoría de precios entre poco menos de los 200,000 y ligeramente pasados los 400,000, con una muy escasa representación en rangos posteriores y anteriores

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
#comparativa de precios promedios entre Valdemorrillo y Galapagar
Promed_Valdemorillo = (ds[ds["level5"] == "Valdemorillo"]["price"].sum()/ds[ds["level5"] == "Valdemorillo"]["price"].count())*100
Promed_Galapagar = (ds[ds["level5"] == "Galapagar"]["price"].sum()/ds[ds["level5"] == "Galapagar"]["price"].count())*100
print(Promed_Valdemorillo)
print(Promed_Galapagar)
# Out:
# 36386029.31034483
# 36006320.23809524

# %% [markdown]
# Se observa una diferencia aunque mínima, existente, por lo que se podría estimar sin ser concluyentes, que podría haber algun rango de similitud de los precios de las viviendas en ambas locaciones, probablemente por compatibilidad demográfica

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# calcular precios por metro cuadrado, añadir nueva columna
metr_cuad_tot = ds.groupby('level5')['surface'].transform('sum')
precio_total = ds.groupby('level5')['price'].transform('sum')
ds['PPS'] = (precio_total / metr_cuad_tot)*100
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
Sum_precio_vald = ds[ds["level5"] == "Valdemorillo"]["price"].sum()
Sum_metr2_vald = ds[ds["level5"] == "Valdemorillo"]["surface"].sum()
Prom_pps_vald = (Sum_precio_vald / Sum_metr2_vald)*100

Sum_precio_Gala = ds[ds["level5"] == "Galapagar"]["price"].sum()
Sum_metr2_Gala = ds[ds["level5"] == "Galapagar"]["surface"].sum()
Prom_pps_Gala = (Sum_precio_Gala / Sum_metr2_Gala)*100

print(Prom_pps_vald)
print(Prom_pps_Gala)
# Out:
# 113761.50611826856
# 131994.88958715196

# %% [markdown]
# Al comparar precios promedio por metro cuadrado en ambos sectores, se observa que no existe una diferencia significativa, por lo que se estima una similitud geo-económica entre ambas localidades

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
plt.figure(figsize=(8, 5))
plt.scatter(ds['surface'], ds['price'], color='blue', alpha=0.7)

plt.xlabel('Superficie (m²)')
plt.ylabel('Precio ($)')
plt.title('Relación entre superficie y precio')

plt.grid(True)

plt.show()

# %% [markdown]
# Con sus excepciones, se observa un incremento constante en el precio, en relación con el incremento de la superficie

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# identificar agencias de bienes raices
Agencias = ds["realEstate_name"].unique()
print("Son ",len(Agencias),"agencias")
# Out:
# Son  1822 agencias

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# que población tiene más casas
población = ds["level5"].unique()
conteo_x_secc = ds["level5"].value_counts()
nombre_mas_pres = conteo_x_secc.idxmax()
Cant_mas_pres = conteo_x_secc.max()
print("Población:",nombre_mas_pres,"; Cant._casas:",Cant_mas_pres)
# Out:
# Población:  Madrid Capital ; Cant._casas: 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# Cinturón sur de Madrid
cinturón_sur = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
ds_subconj = ds["level5"].isin(cinturón_sur)
ds_cint_sur = ds[ds_subconj]
ds_cint_sur
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
Med_precios_cint_sur = ds_cint_sur.groupby(by=["level5"])[["price"]].median()
Med_precios_cint_sur = pd.DataFrame(Med_precios_cint_sur)
print(Med_precios_cint_sur)

Med_precios_cint_sur.plot(kind='bar', legend=False)

# Agregar etiquetas
plt.title('Precio promedio por ciudad')
plt.ylabel('Precio')
plt.xlabel('Ciudad')
plt.xticks(rotation=45)

# Mostrar la gráfica
plt.tight_layout()
plt.show()
# Out:
#                 price
# level5
# Alcorcón     179500.0
# Fuenlabrada  155000.0
# Getafe       285305.0
# Leganés      169950.0

# %% [markdown]
# Se observa que la mediana es relativamente constante entre 3 de las 4 localidades

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# Calcula la media de precio, habitaciones, superficie y baños para cada localidad
Media_cint_sur = ds_cint_sur.groupby(by=["level5"])[["price","rooms","surface","bathrooms"]].mean()
Media_cint_sur
# Out:
#                      price     rooms     surface  bathrooms
# level5
# Alcorcón     230071.052632  2.914894  105.913295   1.623656
# Fuenlabrada  177198.021459  3.025974  103.624365   1.445415
# Getafe       265040.500000  3.151724  126.896266   1.865052
# Leganés      208682.010309  2.906736  105.852273   1.518135

# %%
#Calcula la varianza de precio, habitaciones, superficie y baños, para cada localidad
Var_cint_sur = ds_cint_sur.groupby(by=["level5"])[["price","rooms","surface","bathrooms"]].var()
Var_cint_sur
# Out:
#                     price     rooms      surface  bathrooms
# level5
# Alcorcón     1.594783e+10  0.933895  4244.323834   0.592735
# Fuenlabrada  4.701021e+09  0.355844  2264.643893   0.353367
# Getafe       2.098267e+10  0.772748  5828.110028   0.658809
# Leganés      1.191394e+10  0.824590  3987.475195   0.553055

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# Las casas más caras
Casas_más_caras = ds_cint_sur.groupby(by=["level5"])["price"].max()
Dom_casas_más_caras = ds_cint_sur.groupby('level5')['address'].apply(list)

print(Casas_más_caras)
print(Dom_casas_más_caras)
# Out:
# level5
# Alcorcón        950000
# Fuenlabrada     490000
# Getafe         1050000
# Leganés         650000
# Name: price, dtype: int64
# level5
# Alcorcón       [Avenida Carabancheles, 18, Alcorcón, Alcorcón...
# Fuenlabrada    [Calle Polvoranca, 6, Fuenlabrada, Barrio San ...
# Getafe         [Calle General Castaños, Getafe, Calle Brunete...
# Leganés        [Avenida Los Pinos, Leganés, Del Carmen, Legan...
# Name: address, dtype: object

# %%
df_cint_sur = ds_cint_sur.groupby("level5")["price"] #convoca a la función "groupby" para crear un unevo dataframe

resultados = pd.DataFrame({ #indica los datos que se van a integrar al dataframe
    "Dirección": Dom_casas_más_caras,
    "Precio": Casas_más_caras
}).reset_index()

df_resumen = pd.DataFrame(resultados)
df_resumen
# Out:
#         level5                                          Dirección   Precio
# 0     Alcorcón  [Avenida Carabancheles, 18, Alcorcón, Alcorcón...   950000
# 1  Fuenlabrada  [Calle Polvoranca, 6, Fuenlabrada, Barrio San ...   490000
# 2       Getafe  [Calle General Castaños, Getafe, Calle Brunete...  1050000
# 3      Leganés  [Avenida Los Pinos, Leganés, Del Carmen, Legan...   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
#normalizar precios
ds_cint_sur["Precios_norm"] = (ds_cint_sur["price"] - ds_cint_sur["price"].min()) / (ds_cint_sur["price"].max() - ds_cint_sur["price"].min())
ds_cint_sur = pd.DataFrame(ds_cint_sur)
print(type(ds_cint_sur))
print(ds_cint_sur["Precios_norm"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 1        0.084762
# 3        0.084762
# 85       0.101905
# 94       0.304762
# 109      0.404762
#            ...
# 15275    0.131429
# 15291    0.265714
# 15305    0.161905
# 15322    0.106667
# 15325    0.204762
# Name: Precios_norm, Length: 907, dtype: float64
# C:\Users\Angel Resendiz Plata\AppData\Local\Temp\ipykernel_10648\293597543.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_cint_sur["Precios_norm"] = (ds_cint_sur["price"] - ds_cint_sur["price"].min()) / (ds_cint_sur["price"].max() - ds_cint_sur["price"].min())

# %%
plt.hist(ds_cint_sur["Precios_norm"], bins=6, color='skyblue', edgecolor='black')

# Agregar etiquetas
plt.title("Distribución de precios")
plt.xlabel("level5")
plt.ylabel("precios")

# Mostrar gráfico
plt.show()

# %% [markdown]
# La curva se vuelve una recta en la gráfica, hay una equidistancia apreciable entre los picos de cada localidad en lo que respecta a los precios normalizados

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# Análisis precio por metro cuadrado de "Getafe" y "Alcorcón"
medio_cint = ["Getafe", "Alcorcón"]
ds_subconj = ds["level5"].isin(medio_cint)
ds_medio_cint = ds[ds_subconj]
pd.DataFrame(ds_medio_cint).head()
# Out:
#      Unnamed: 0  id_realEstates  isNew                  realEstate_name  \
# 85           86       153152077  False          sinergical inmobiliaria
# 109         110       153586414  False  area uno asesores inmobiliarios
# 169         170       153920011  False                     grupo tizona
# 232         233       152842726  False              aljada inmobiliaria
# 233         234       152842686  False              aljada inmobiliaria
#
#      phone_realEstate                                       url_inmueble  \
# 85                NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109       912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 169       911226046.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 232       916355578.0  https://www.fotocasa.es/es/comprar/vivienda/sa...
# 233       916355578.0  https://www.fotocasa.es/es/comprar/vivienda/sa...
#
#      rooms  bathrooms  surface   price  ... level5Id level6Id level7Id  \
# ...

# %% [markdown]
# Considerando el monto de los precios por metro cuadrado promediados, se observa que la diferencia no es significativa entre ambos

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
ds["level5"].unique()
# Out:
# array(['Arganda del Rey', 'Fuenlabrada', 'Boadilla del Monte',
#        'Las Rozas de Madrid', ' Madrid Capital', 'Villaviciosa de Odón',
#        'Pinto', 'Valdemoro', 'Navalcarnero', 'Pozuelo de Alarcón',
#        'Torrejón de Ardoz', 'Navalagamella', 'San Sebastián de los Reyes',
#        'Rivas-vaciamadrid', 'Alpedrete', 'Móstoles',
#        'San Fernando de Henares', 'Coslada', 'Becerril de la Sierra',
#        'Alcalá de Henares', 'Chinchón', 'Parla', 'Alcorcón',
#        'El Escorial', 'Leganés', 'Pedrezuela', 'Majadahonda',
#        'Villanueva de la Cañada', 'Villanueva del Pardillo',
#        'Torrelodones', 'Moralzarzal', 'Mejorada del Campo', 'Aranjuez',
#        'Corpa', 'Getafe', 'Velilla de San Antonio', 'Sevilla la Nueva',
#        'San Martín de la Vega', 'Villalbilla', 'Collado Villalba',
#        'Alcobendas', 'El Molar (Madrid)', 'Moraleja de Enmedio', 'Algete',
#        'Campo Real', 'Torrejón de la Calzada', 'Colmenar Viejo',
# ...

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
pip install ipyleaflet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ipyleaflet-0.20.0-py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached jupyter_leaflet-0.20.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# ...
# Using cached ipyleaflet-0.20.0-py3-none-any.whl (31 kB)
# Using cached jupyter_leaflet-0.20.0-py3-none-any.whl (1.1 MB)
# Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Using cached branca-0.8.1-py3-none-any.whl (26 kB)
# Using cached xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# ...
#
#    -------- ------------------------------- 1/5 [traittypes]
#    ---------------- ----------------------- 2/5 [jupyter-leaflet]
#    ------------------------ --------------- 3/5 [branca]
#    -------------------------------- ------- 4/5 [ipyleaflet]
# ...

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en Madrid
map = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
# Cinturón sur de Madrid
cinturón_sur = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
ds_subconj = ds["level5"].isin(cinturón_sur)
ds_cint_sur = ds[ds_subconj]
ds_cint_sur
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %%
from ipyleaflet import Map, basemaps, CircleMarker, MarkerCluster

Mapa = Map(center=(40.4168, -3.7038), zoom=10, basemap=basemaps.OpenStreetMap.Mapnik)

# Lista para guardar los marcadores
markers = []

# Crear un CircleMarker para cada fila
for _, row in ds_cint_sur.iterrows():
    circle = CircleMarker(
        location=(row["latitude"], row["longitude"]),
        radius=1000,             # tamaño del círculo
        color="red",           # borde rojo
        fill_color="black",   # relleno amarillo
        fill_opacity=1,      # transparencia del relleno
        stroke=True,           # dibujar el borde
        weight=10               # grosor del borde
    )
    markers.append(circle)

# Agrupar en un cluster (opcional si hay muchos puntos)
marker_cluster = MarkerCluster(markers=markers)

# Añadir al mapa
Mapa.add_layer(marker_cluster)

Mapa
# Out:
# Map(center=[40.4168, -3.7038], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…
